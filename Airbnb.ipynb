# %%
import numpy as np
import pandas as pd

# %%
import urllib.request
from pathlib import Path
import os
path = Path()

# Dictionary of file names and download links
files = {'listings.csv':'http://data.insideairbnb.com/united-states/ny/new-york-city/2020-09-07/visualisations/listings.csv'}

# Download each file
for key,value in files.items():
    filename = path/key
    url = value
    # If the file does not already exist in the directory, download it
    if not os.path.exists(filename):
        urllib.request.urlretrieve(url,filename)

# %%
Airbnb = pd.read_csv('listings.csv')
Airbnb.shape
Airbnb['neighbourhood_group'].unique()
# Out:
# array(['Manhattan', 'Brooklyn', 'Queens', 'Staten Island', 'Bronx'],
#       dtype=object)

# %%
print(list(Airbnb.columns))
# Out:
# ['id', 'name', 'host_id', 'host_name', 'neighbourhood_group', 'neighbourhood', 'latitude', 'longitude', 'room_type', 'price', 'minimum_nights', 'number_of_reviews', 'last_review', 'reviews_per_month', 'calculated_host_listings_count', 'availability_365']

# %%
# Keep columns that would be useful for analysis
AirbnbInfo = Airbnb[['id','name','latitude','longitude', 'room_type', 'price', 'availability_365', 'neighbourhood_group']]

# %%
AirbnbInfo.head()
# Out:
#      id                                               name  latitude  \
# 0  2595                              Skylit Midtown Castle  40.75362
# 1  3831  Whole flr w/private bdrm, bath & kitchen(pls r...  40.68514
# 2  5121                                    BlissArtsSpace!  40.68688
# 3  5136           Spacious Brooklyn Duplex, Patio + Garden  40.66120
# 4  5178                   Large Furnished Room Near B'way　  40.76489
#
#    longitude        room_type  price  availability_365 neighbourhood_group
# 0  -73.98377  Entire home/apt    175               365           Manhattan
# 1  -73.95976  Entire home/apt     76               272            Brooklyn
# 2  -73.95596     Private room     60               365            Brooklyn
# 3  -73.99423  Entire home/apt    175               352            Brooklyn
# 4  -73.98493     Private room     79               346           Manhattan

# %%
# Drop the rows with zero availability of a year
AirbnbInfo = AirbnbInfo[AirbnbInfo['availability_365'] != 0]
AirbnbInfo = AirbnbInfo.reset_index(drop=True)
AirbnbInfo
# Out:
#              id                                               name   latitude  \
# 0          2595                              Skylit Midtown Castle  40.753620
# 1          3831  Whole flr w/private bdrm, bath & kitchen(pls r...  40.685140
# 2          5121                                    BlissArtsSpace!  40.686880
# 3          5136           Spacious Brooklyn Duplex, Patio + Garden  40.661200
# 4          5178                   Large Furnished Room Near B'way　  40.764890
# ...         ...                                                ...        ...
# 25643  45327718           Spacious 1 Queen Bedroom in Central Park  40.802660
# 25644  45329132            5,000 sq ft Downtown Brooklyn Penthouse  40.687770
# 25645  45329491                Spacious 1 Queen Bedroom in Tribeca  40.713630
# 25646  45329984             Spacious 1 Full Bedroom in Murray Hill  40.744800
# 25647  45330395                Cozy Studio in a Brand New Building  40.767254
#
#        longitude        room_type  price  availability_365 neighbourhood_group
# 0     -73.983770  Entire home/apt    175               365           Manhattan
# 1     -73.959760  Entire home/apt     76               272            Brooklyn
# 2     -73.955960     Private room     60               365            Brooklyn
# 3     -73.994230  Entire home/apt    175               352            Brooklyn
# 4     -73.984930     Private room     79               346           Manhattan
# ...          ...              ...    ...               ...                 ...
# 25643 -73.958360     Private room     53               365           Manhattan
# 25644 -73.982390     Private room     79               361            Brooklyn
# 25645 -74.008470     Private room     70               364           Manhattan
# 25646 -73.977500     Private room     59               365           Manhattan
# 25647 -73.990176  Entire home/apt     75               336           Manhattan
#
# [25648 rows x 8 columns]

# %%
# Store the cleaned data to a new csv file
AirbnbInfo.to_csv('Cleaned_Airbnb.csv')

# %%
Airbnbnew = Airbnb.copy()
Airbnbnew = Airbnbnew[Airbnbnew['availability_365'] != 0]
Airbnbnew = Airbnbnew.reset_index(drop=True)
Airbnb_price = Airbnbnew[['id','name','latitude','longitude','neighbourhood_group','neighbourhood','room_type','price']]
Airbnb_price
# Out:
#              id                                               name   latitude  \
# 0          2595                              Skylit Midtown Castle  40.753620
# 1          3831  Whole flr w/private bdrm, bath & kitchen(pls r...  40.685140
# 2          5121                                    BlissArtsSpace!  40.686880
# 3          5136           Spacious Brooklyn Duplex, Patio + Garden  40.661200
# 4          5178                   Large Furnished Room Near B'way　  40.764890
# ...         ...                                                ...        ...
# 25643  45327718           Spacious 1 Queen Bedroom in Central Park  40.802660
# 25644  45329132            5,000 sq ft Downtown Brooklyn Penthouse  40.687770
# 25645  45329491                Spacious 1 Queen Bedroom in Tribeca  40.713630
# 25646  45329984             Spacious 1 Full Bedroom in Murray Hill  40.744800
# 25647  45330395                Cozy Studio in a Brand New Building  40.767254
#
#        longitude neighbourhood_group       neighbourhood        room_type  \
# 0     -73.983770           Manhattan             Midtown  Entire home/apt
# 1     -73.959760            Brooklyn        Clinton Hill  Entire home/apt
# 2     -73.955960            Brooklyn  Bedford-Stuyvesant     Private room
# 3     -73.994230            Brooklyn         Sunset Park  Entire home/apt
# 4     -73.984930           Manhattan      Hell's Kitchen     Private room
# ...          ...                 ...                 ...              ...
# 25643 -73.958360           Manhattan              Harlem     Private room
# 25644 -73.982390            Brooklyn         Boerum Hill     Private room
# 25645 -74.008470           Manhattan             Tribeca     Private room
# 25646 -73.977500           Manhattan            Kips Bay     Private room
# 25647 -73.990176           Manhattan      Hell's Kitchen  Entire home/apt
#
#        price
# 0        175
# 1         76
# 2         60
# 3        175
# 4         79
# ...      ...
# 25643     53
# 25644     79
# 25645     70
# 25646     59
# 25647     75
#
# [25648 rows x 8 columns]

# %%
from scipy import stats
import matplotlib.pyplot as plt
import statsmodels.api as sm
from statsmodels.formula.api import ols

# %%
Airbnb_price.isnull().sum()
# Out:
# id                     0
# name                   5
# latitude               0
# longitude              0
# neighbourhood_group    0
# neighbourhood          0
# room_type              0
# price                  0
# dtype: int64

# %%
AB_neighbourhood = Airbnb_price[['neighbourhood','room_type','price']].groupby(['neighbourhood','room_type']).agg(['mean','std'])
AB_neighbourhood.columns = AB_neighbourhood.columns.droplevel()
AB_neighbourhood
# Out:
#                                      mean         std
# neighbourhood room_type
# Allerton      Entire home/apt  179.230769  226.431798
#               Private room      57.333333   17.981472
# Arden Heights Entire home/apt  145.000000   46.486557
#               Private room     125.000000         NaN
# Arrochar      Entire home/apt  200.666667  204.465156
# ...                                   ...         ...
# Woodlawn      Entire home/apt  176.000000   86.007752
#               Private room      61.000000   24.248711
# Woodside      Entire home/apt  159.642857   67.365897
#               Private room      46.532468   27.596905
#               Shared room       62.500000   58.523500
#
# [537 rows x 2 columns]

# %%
newAB = pd.merge(Airbnb_price, AB_neighbourhood, on=['neighbourhood','room_type'], how='outer')
newAB
# Out:
#              id                                               name  latitude  \
# 0          2595                              Skylit Midtown Castle  40.75362
# 1         59855                            One bedroom Apt. in NYC  40.75890
# 2        110739  Central Nomad/Chelsea Loft Studio - metro dnst...  40.74503
# 3        235951              Stylish Studio with exclusive Terrace  40.75348
# 4        271694                Easy, comfortable studio in Midtown  40.75282
# ...         ...                                                ...       ...
# 25643  43836149     Studio Monarch - Photography & Production Only  40.67767
# 25644  44224775          Stunning 2-people shared close to M train  40.70224
# 25645  44322911                                       Oakwood Room  40.56436
# 25646  44491496                          COMFY COZY PLACE TO CRASH  40.60785
# 25647  45254583  Comfort Station Next Door To Subway/Barclays/P...  40.68941
#
#        longitude neighbourhood_group neighbourhood        room_type  price  \
# 0      -73.98377           Manhattan       Midtown  Entire home/apt    175
# 1      -73.96991           Manhattan       Midtown  Entire home/apt    250
# 2      -73.98876           Manhattan       Midtown  Entire home/apt    110
# 3      -73.97065           Manhattan       Midtown  Entire home/apt    135
# 4      -73.97315           Manhattan       Midtown  Entire home/apt    125
# ...          ...                 ...           ...              ...    ...
# 25643  -74.00740            Brooklyn      Red Hook      Shared room    120
# 25644  -73.90637              Queens     Ridgewood      Shared room     20
# 25645  -74.13019       Staten Island       Oakwood     Private room    150
# 25646  -73.91319            Brooklyn    Mill Basin      Shared room     85
# 25647  -73.96108            Brooklyn  Clinton Hill      Shared room     28
#
#              mean         std
# 0      265.455944  270.919813
# 1      265.455944  270.919813
# 2      265.455944  270.919813
# 3      265.455944  270.919813
# 4      265.455944  270.919813
# ...           ...         ...
# 25643  120.000000         NaN
# 25644   20.000000         NaN
# 25645  150.000000         NaN
# 25646   85.000000         NaN
# 25647   28.000000         NaN
#
# [25648 rows x 10 columns]

# %%
newAB.isnull().sum()
# Out:
# id                      0
# name                    5
# latitude                0
# longitude               0
# neighbourhood_group     0
# neighbourhood           0
# room_type               0
# price                   0
# mean                    0
# std                    78
# dtype: int64

# %%
newAB['zscore']= (newAB['price']-newAB['mean'])/newAB['std']
#the null value in standard deviation is because there's one listing in that area
#and std performs over N-1
#the null value is Z is because of null value in standard deviation
#so back fill with 0 because there's only one listing
newAB['zscore'] = newAB['zscore'].fillna(0)
newAB
# Out:
#              id                                               name  latitude  \
# 0          2595                              Skylit Midtown Castle  40.75362
# 1         59855                            One bedroom Apt. in NYC  40.75890
# 2        110739  Central Nomad/Chelsea Loft Studio - metro dnst...  40.74503
# 3        235951              Stylish Studio with exclusive Terrace  40.75348
# 4        271694                Easy, comfortable studio in Midtown  40.75282
# ...         ...                                                ...       ...
# 25643  43836149     Studio Monarch - Photography & Production Only  40.67767
# 25644  44224775          Stunning 2-people shared close to M train  40.70224
# 25645  44322911                                       Oakwood Room  40.56436
# 25646  44491496                          COMFY COZY PLACE TO CRASH  40.60785
# 25647  45254583  Comfort Station Next Door To Subway/Barclays/P...  40.68941
#
#        longitude neighbourhood_group neighbourhood        room_type  price  \
# 0      -73.98377           Manhattan       Midtown  Entire home/apt    175
# 1      -73.96991           Manhattan       Midtown  Entire home/apt    250
# 2      -73.98876           Manhattan       Midtown  Entire home/apt    110
# 3      -73.97065           Manhattan       Midtown  Entire home/apt    135
# 4      -73.97315           Manhattan       Midtown  Entire home/apt    125
# ...          ...                 ...           ...              ...    ...
# 25643  -74.00740            Brooklyn      Red Hook      Shared room    120
# 25644  -73.90637              Queens     Ridgewood      Shared room     20
# 25645  -74.13019       Staten Island       Oakwood     Private room    150
# 25646  -73.91319            Brooklyn    Mill Basin      Shared room     85
# 25647  -73.96108            Brooklyn  Clinton Hill      Shared room     28
#
#              mean         std    zscore
# 0      265.455944  270.919813 -0.333885
# 1      265.455944  270.919813 -0.057050
# 2      265.455944  270.919813 -0.573808
# 3      265.455944  270.919813 -0.481530
# 4      265.455944  270.919813 -0.518441
# ...           ...         ...       ...
# 25643  120.000000         NaN  0.000000
# 25644   20.000000         NaN  0.000000
# 25645  150.000000         NaN  0.000000
# 25646   85.000000         NaN  0.000000
# 25647   28.000000         NaN  0.000000
#
# [25648 rows x 11 columns]

# %%
outlier = newAB.loc[(newAB['zscore']>3) ^ (newAB['zscore']<-3)]
outlier
# Out:
#              id                                               name  latitude  \
# 65      8810949                  NYC  Upscale Midtown East 3BR Apt  40.74867
# 108    12870225                  Fab 3BR UN Plaza with River Views  40.75260
# 140    14408114           Unparalleled Luxury in Midtown Manhattan  40.76455
# 155    15347268  Modern Luxury 2 Bed/ 2 Bath apartment in Midtown!  40.75425
# 159    15857259        5 Star Luxury 2 BR Suite Heart of Manhattan  40.76110
# ...         ...                                                ...       ...
# 25170  34518079       Park Avenue Suite with Large Outdoor Terrace  40.74392
# 25171  34518082  Approx. 980 sqft Suite with Large Outdoor Terrace  40.74392
# 25366  41348519                               Attic with Queen Bed  40.81512
# 25395  34718633                                 Mott Haven Dorm CC  40.80893
# 25490  34470953                Chelsea Pines Inn - Hide Away Suite  40.73968
#
#        longitude neighbourhood_group neighbourhood        room_type  price  \
# 65     -73.96734           Manhattan       Midtown  Entire home/apt   1170
# 108    -73.96789           Manhattan       Midtown  Entire home/apt   1100
# 140    -73.97959           Manhattan       Midtown  Entire home/apt   2500
# 155    -73.98312           Manhattan       Midtown  Entire home/apt   2000
# 159    -73.97412           Manhattan       Midtown  Entire home/apt   1999
# ...          ...                 ...           ...              ...    ...
# 25170  -73.98638           Manhattan       Midtown       Hotel room   1286
# 25171  -73.98638           Manhattan       Midtown       Hotel room   1186
# 25366  -73.81752               Bronx   Throgs Neck     Private room    105
# 25395  -73.93111               Bronx   Port Morris      Shared room     24
# 25490  -74.00455           Manhattan  West Village       Hotel room    362
#
#              mean         std    zscore
# 65     265.455944  270.919813  3.338789
# 108    265.455944  270.919813  3.080410
# 140    265.455944  270.919813  8.247991
# 155    265.455944  270.919813  6.402426
# 159    265.455944  270.919813  6.398735
# ...           ...         ...       ...
# 25170  321.797297  270.957510  3.558501
# 25171  321.797297  270.957510  3.189440
# 25366   52.933333   16.628146  3.131237
# 25395   24.909091    0.301511 -3.015113
# 25490  124.000000   75.871902  3.136866
#
# [409 rows x 11 columns]

# %%
#delete the airbnb that has outlying prices from our dataset
FinalAB = newAB.loc[(newAB['zscore']>3) ^ (newAB['zscore']<-3)]
FinalAB = FinalAB[['id','name','latitude','longitude', 'room_type', 'price']]
FinalAB.to_csv('Final_Airbnb.csv')
